# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.rc("figure", figsize = (14, 6))
dados = pd.read_csv("dados/aluguel_residencial.csv", sep = ";")
dados.boxplot(["Valor"])

# %%
dados[dados["Valor"] >= 500000]
valor = dados['Valor']

# %% [markdown]
# # Para Fazer um upload de imagens(tag mg html)

# %% [markdown]
# <img src="compressed_box-plot.png" width=70%>

# %%
# Para calcular o box-plot e "jogar fora" os dados que estão divergindo 
Q1 = valor.quantile(.25)
Q3 = valor.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
selecao = (valor >= limite_inferior) & (valor <= limite_superior)
dados_new = dados[selecao]
dados_new.boxplot(["Valor"])

# %%
dados.hist(["Valor"])
dados_new.hist(["Valor"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CEDE7F9F10>]],
#       dtype=object)
